# %%
import pandas as pd
import numpy as np
# %config Completer.use_jedi = False\

# %%
iris=pd.read_csv('C:\Varun\Work\ANALYTICS PATH\Project\Iris.csv')

# %%
dd=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
#we dont know howmany tables are available in html, then check len of that html. Len will give no of tables in list
len(dd)
# Out:
# 1

# %%
dd[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
dd[0].head(6)
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
# 5  5  Arron Afflalo  SG  29  DEN  53  53  1750  281  657  ...  .841   21  159
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
# 5  180  101  32   5   83  108   771
#
# [6 rows x 30 columns]

# %%
dd1=pd.DataFrame(dd[0])

# %%
dd1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
dd1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
dd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      675 non-null    object
#  1   Player  675 non-null    object
#  2   Pos     675 non-null    object
#  3   Age     675 non-null    object
#  4   Tm      675 non-null    object
#  5   G       675 non-null    object
#  6   GS      675 non-null    object
#  7   MP      675 non-null    object
#  8   FG      675 non-null    object
#  9   FGA     675 non-null    object
#  10  FG%     673 non-null    object
#  11  3P      675 non-null    object
#  12  3PA     675 non-null    object
#  13  3P%     594 non-null    object
#  14  2P      675 non-null    object
#  15  2PA     675 non-null    object
#  16  2P%     671 non-null    object
#  17  eFG%    673 non-null    object
#  18  FT      675 non-null    object
#  19  FTA     675 non-null    object
#  20  FT%     650 non-null    object
# ...

# %%
#Data Manupulation

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
titanic=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.dtypes[titanic.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic[titanic.dtypes[titanic.dtypes=='int64'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
titanic[titanic.dtypes[titanic.dtypes=='float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
titanic[titanic.dtypes[(titanic.dtypes=='float64')|(titanic.dtypes=='int64')].index]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
titanic["Age"].isnull()==True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
#fecthing all null values in age
nulldata=np.where(titanic["Age"].isnull()==True)

# %%
#iloc and loc

# %%
#integer location (row)
titanic.iloc[[0,2,3]]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
#
#              Ticket    Fare Cabin Embarked
# 0         A/5 21171   7.250   NaN        S
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S

# %%
#using nulldata list to get all details of null values of Age
titanic.iloc[nulldata]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.iloc[nulldata]["Name"]
# Out:
# 5                              Moran, Mr. James
# 17                 Williams, Mr. Charles Eugene
# 19                      Masselmani, Mrs. Fatima
# 26                      Emir, Mr. Farred Chehab
# 28                O'Dwyer, Miss. Ellen "Nellie"
#                          ...
# 859                            Razi, Mr. Raihed
# 863           Sage, Miss. Dorothy Edith "Dolly"
# 868                 van Melkebeke, Mr. Philemon
# 878                          Laleff, Mr. Kristo
# 888    Johnston, Miss. Catherine Helen "Carrie"
# Name: Name, Length: 177, dtype: object

# %%
titanic["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
maxfair=np.where(titanic["Fare"]==max(titanic["Fare"]))

# %%
titanic.iloc[maxfair]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
titanic.iloc[maxfair]["Name"]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic.iloc[np.where(titanic["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#we can use above or this code to filter data
titanic[titanic["Sex"]=="female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic["Fare"]==max(titanic["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
titanic["Cabin"]=="C85"
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Cabin, Length: 891, dtype: bool

# %%
titanic[(titanic["Cabin"]=="C85")&(titanic["SibSp"]==1)]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %%
titanic["Newcolumn"]=titanic["Pclass"]+titanic["SibSp"]

# %%
titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  Newcolumn
# 0      0  A/5 21171  7.25   NaN        S          4

# %%
titanic[titanic["Age"]==max(titanic["Age"])]["Name"]
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
titanic.drop("Newcolumn",axis=1,inplace=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.drop(["PassengerId","Sex","Fare"],axis=1,inplace=True)

# %%
titanic.head()
# Out:
#    Survived  Pclass                                               Name   Age  \
# 0         0       3                            Braund, Mr. Owen Harris  22.0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2         1       3                             Heikkinen, Miss. Laina  26.0
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4         0       3                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch            Ticket Cabin Embarked
# 0      1      0         A/5 21171   NaN        S
# 1      1      0          PC 17599   C85        C
# 2      0      0  STON/O2. 3101282   NaN        S
# 3      1      0            113803  C123        S
# 4      0      0            373450   NaN        S

# %%
titanic.drop([1,5],axis=0,inplace=True)

# %%
titanic
# Out:
#      Survived  Pclass                                          Name   Age  \
# 0           0       3                       Braund, Mr. Owen Harris  22.0
# 2           1       3                        Heikkinen, Miss. Laina  26.0
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4           0       3                      Allen, Mr. William Henry  35.0
# 6           0       1                       McCarthy, Mr. Timothy J  54.0
# ..        ...     ...                                           ...   ...
# 886         0       2                         Montvila, Rev. Juozas  27.0
# 887         1       1                  Graham, Miss. Margaret Edith  19.0
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889         1       1                         Behr, Mr. Karl Howell  26.0
# 890         0       3                           Dooley, Mr. Patrick  32.0
#
#      SibSp  Parch            Ticket Cabin Embarked
# ...

# %%
titanic.drop([6:10],axis=0,inplace=True)
# Out:
#   File "<ipython-input-97-c48cfd0d5f17>", line 1
#     titanic.drop([6:10],axis=0,inplace=True)
#                    ^
# SyntaxError: invalid syntax

# %%
titanic[titanic["Age"]>30]
# Out:
#      Survived  Pclass                                           Name   Age  \
# 3           1       1   Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4           0       3                       Allen, Mr. William Henry  35.0
# 6           0       1                        McCarthy, Mr. Timothy J  54.0
# 11          1       1                       Bonnell, Miss. Elizabeth  58.0
# 13          0       3                    Andersson, Mr. Anders Johan  39.0
# ..        ...     ...                                            ...   ...
# 873         0       3                    Vander Cruyssen, Mr. Victor  47.0
# 879         1       1  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 881         0       3                             Markun, Mr. Johann  33.0
# 885         0       3           Rice, Mrs. William (Margaret Norton)  39.0
# 890         0       3                            Dooley, Mr. Patrick  32.0
#
#      SibSp  Parch  Ticket Cabin Embarked
# ...

# %%
#Dropna(threshold)
#fillna

# %%
titanic["Age"].fillna(value=titanic["Age"].mean())

# %%
# Out:
# 0      22.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
# 6      54.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.687475
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 889, dtype: float64

# %%
pwd()
# Out:
# 'C:\\Users\\varun'

# %%
path="C:\Varun\Work\ANALYTICS PATH\ineuron\assignment\bending1"

# %%
open('c:\Varun\Work\ANALYTICS PATH\ineuron\assignment\bending1\Dataset10.csv','r')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-43-6000c6fe8e14> in <module>
# ----> 1 open('c:\Varun\Work\ANALYTICS PATH\ineuron\assignment\bending1\Dataset10.csv','r')
#
# OSError: [Errno 22] Invalid argument: 'c:\\Varun\\Work\\ANALYTICS PATH\\ineuron\x07ssignment\x08ending1\\Dataset10.csv'
